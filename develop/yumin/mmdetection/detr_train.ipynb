# %%
# 모듈 import

from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)
from mmdet.utils import get_device

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./configs/_custom_/co_detr.py')

root='../../../dataset/'

# dataset config 수정
cfg.data.train.classes = classes
cfg.data.train.img_prefix = root
cfg.data.train.ann_file = root + 'updated_train.json' # train json 정보

cfg.data.test.classes = classes
cfg.data.test.img_prefix = root
cfg.data.test.ann_file = root + 'test.json' # test json 정보

cfg.data.samples_per_gpu = 8

cfg.seed = 2022
cfg.gpu_ids = [0]
cfg.work_dir = './work_dirs/cascade_rcnn_r50_fpn_1x_swin_trash'

cfg.model.roi_head.bbox_head[0].num_classes = 10
cfg.model.roi_head.bbox_head[1].num_classes = 10
cfg.model.roi_head.bbox_head[2].num_classes = 10


cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.checkpoint_config = dict(max_keep_ckpts=3, interval=1)
cfg.device = get_device()

# %%
# build_dataset
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!

# %%
# dataset 확인
datasets[0]
# Out:
# CocoDataset Train dataset with number of images 4875, and instance counts:
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | category          | count | category      | count | category        | count | category    | count | category     | count |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | 0 [General trash] | 3926  | 1 [Paper]     | 6230  | 2 [Paper pack]  | 890   | 3 [Metal]   | 849   | 4 [Glass]    | 977   |
# | 5 [Plastic]       | 2873  | 6 [Styrofoam] | 1225  | 7 [Plastic bag] | 5143  | 8 [Battery] | 159   | 9 [Clothing] | 463   |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+

# %%
# 모델 build 및 pretrained network 불러오기
model = build_detector(cfg.model)
model.init_weights()
# Out:
# 2024-01-14 01:44:57,714 - mmdet - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2024-01-14 01:44:57,715 - mmcv - INFO - load model from: torchvision://resnet50
# 2024-01-14 01:44:57,716 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2024-01-14 01:44:57,806 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2024-01-14 01:44:57,821 - mmdet - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2024-01-14 01:44:57,846 - mmdet - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2024-01-14 01:44:57,852 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2024-01-14 01:44:57,953 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2024-01-14 01:44:58,054 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2024-01-14 01:44:58,231 - mmdet - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,232 - mmdet - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,233 - mmdet - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,233 - mmdet - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,234 - mmdet - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,234 - mmdet - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,235 - mmdet - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,235 - mmdet - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,236 - mmdet - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,237 - mmdet - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,237 - mmdet - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,238 - mmdet - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,238 - mmdet - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,239 - mmdet - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,239 - mmdet - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,240 - mmdet - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,240 - mmdet - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,241 - mmdet - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,241 - mmdet - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,241 - mmdet - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,242 - mmdet - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,242 - mmdet - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,243 - mmdet - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,243 - mmdet - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,243 - mmdet - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,244 - mmdet - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,244 - mmdet - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,245 - mmdet - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,245 - mmdet - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,246 - mmdet - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,248 - mmdet - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,248 - mmdet - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,249 - mmdet - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,249 - mmdet - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,250 - mmdet - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,250 - mmdet - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,251 - mmdet - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,251 - mmdet - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,252 - mmdet - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,252 - mmdet - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,253 - mmdet - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,253 - mmdet - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,253 - mmdet - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,254 - mmdet - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,254 - mmdet - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,255 - mmdet - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,255 - mmdet - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,256 - mmdet - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,256 - mmdet - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,257 - mmdet - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,257 - mmdet - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,258 - mmdet - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,258 - mmdet - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,258 - mmdet - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,259 - mmdet - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,260 - mmdet - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,260 - mmdet - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,260 - mmdet - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,261 - mmdet - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,261 - mmdet - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,262 - mmdet - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,262 - mmdet - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,263 - mmdet - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,263 - mmdet - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,263 - mmdet - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,264 - mmdet - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,264 - mmdet - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,265 - mmdet - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,266 - mmdet - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,266 - mmdet - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,266 - mmdet - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,267 - mmdet - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,267 - mmdet - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,268 - mmdet - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,268 - mmdet - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,269 - mmdet - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,269 - mmdet - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,269 - mmdet - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,270 - mmdet - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,270 - mmdet - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,271 - mmdet - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,271 - mmdet - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,272 - mmdet - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,272 - mmdet - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,273 - mmdet - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,273 - mmdet - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,275 - mmdet - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,275 - mmdet - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,275 - mmdet - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,276 - mmdet - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,276 - mmdet - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,277 - mmdet - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,277 - mmdet - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,278 - mmdet - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,278 - mmdet - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,278 - mmdet - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,279 - mmdet - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,279 - mmdet - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,280 - mmdet - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,280 - mmdet - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,281 - mmdet - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,281 - mmdet - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,282 - mmdet - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,282 - mmdet - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,283 - mmdet - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,283 - mmdet - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,284 - mmdet - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,284 - mmdet - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,284 - mmdet - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,285 - mmdet - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,285 - mmdet - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,286 - mmdet - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,286 - mmdet - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,287 - mmdet - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,287 - mmdet - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,287 - mmdet - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,288 - mmdet - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,288 - mmdet - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,289 - mmdet - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,289 - mmdet - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,290 - mmdet - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,290 - mmdet - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,290 - mmdet - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,291 - mmdet - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,291 - mmdet - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,292 - mmdet - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,292 - mmdet - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,293 - mmdet - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,293 - mmdet - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,294 - mmdet - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,294 - mmdet - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,294 - mmdet - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,295 - mmdet - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,295 - mmdet - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,296 - mmdet - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,296 - mmdet - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,297 - mmdet - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,297 - mmdet - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,298 - mmdet - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,298 - mmdet - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,298 - mmdet - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,299 - mmdet - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,299 - mmdet - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,300 - mmdet - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,300 - mmdet - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,303 - mmdet - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,304 - mmdet - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,304 - mmdet - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,305 - mmdet - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,305 - mmdet - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,305 - mmdet - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,306 - mmdet - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,306 - mmdet - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,307 - mmdet - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,307 - mmdet - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,308 - mmdet - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,308 - mmdet - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,309 - mmdet - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,309 - mmdet - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-01-14 01:44:58,310 - mmdet - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 256, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,310 - mmdet - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,311 - mmdet - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,311 - mmdet - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,312 - mmdet - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,312 - mmdet - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,313 - mmdet - INFO -
# neck.lateral_convs.3.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,313 - mmdet - INFO -
# neck.lateral_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,313 - mmdet - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,314 - mmdet - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,314 - mmdet - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,315 - mmdet - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,315 - mmdet - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,316 - mmdet - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,316 - mmdet - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,316 - mmdet - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of CascadeRCNN
#
# 2024-01-14 01:44:58,317 - mmdet - INFO -
# rpn_head.rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,317 - mmdet - INFO -
# rpn_head.rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,318 - mmdet - INFO -
# rpn_head.rpn_cls.weight - torch.Size([3, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,318 - mmdet - INFO -
# rpn_head.rpn_cls.bias - torch.Size([3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,319 - mmdet - INFO -
# rpn_head.rpn_reg.weight - torch.Size([12, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,326 - mmdet - INFO -
# rpn_head.rpn_reg.bias - torch.Size([12]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,336 - mmdet - INFO -
# roi_head.bbox_head.0.fc_cls.weight - torch.Size([11, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,336 - mmdet - INFO -
# roi_head.bbox_head.0.fc_cls.bias - torch.Size([11]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,337 - mmdet - INFO -
# roi_head.bbox_head.0.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-01-14 01:44:58,337 - mmdet - INFO -
# roi_head.bbox_head.0.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-01-14 01:44:58,338 - mmdet - INFO -
# roi_head.bbox_head.0.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,339 - mmdet - INFO -
# roi_head.bbox_head.0.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,339 - mmdet - INFO -
# roi_head.bbox_head.0.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,340 - mmdet - INFO -
# roi_head.bbox_head.0.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,341 - mmdet - INFO -
# roi_head.bbox_head.1.fc_cls.weight - torch.Size([11, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,341 - mmdet - INFO -
# roi_head.bbox_head.1.fc_cls.bias - torch.Size([11]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,342 - mmdet - INFO -
# roi_head.bbox_head.1.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-01-14 01:44:58,342 - mmdet - INFO -
# roi_head.bbox_head.1.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-01-14 01:44:58,343 - mmdet - INFO -
# roi_head.bbox_head.1.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,343 - mmdet - INFO -
# roi_head.bbox_head.1.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,344 - mmdet - INFO -
# roi_head.bbox_head.1.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,344 - mmdet - INFO -
# roi_head.bbox_head.1.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,345 - mmdet - INFO -
# roi_head.bbox_head.2.fc_cls.weight - torch.Size([11, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,346 - mmdet - INFO -
# roi_head.bbox_head.2.fc_cls.bias - torch.Size([11]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-01-14 01:44:58,346 - mmdet - INFO -
# roi_head.bbox_head.2.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-01-14 01:44:58,347 - mmdet - INFO -
# roi_head.bbox_head.2.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2024-01-14 01:44:58,347 - mmdet - INFO -
# roi_head.bbox_head.2.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,348 - mmdet - INFO -
# roi_head.bbox_head.2.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,348 - mmdet - INFO -
# roi_head.bbox_head.2.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-01-14 01:44:58,348 - mmdet - INFO -
# roi_head.bbox_head.2.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0

# %%
# 모델 학습
train_detector(model, datasets[0], cfg, distributed=False, validate=False)
# Out:
# 2024-01-14 01:44:58,444 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2024-01-14 01:44:58,447 - mmdet - INFO - Start running, host: root@instance-5750, work_dir: /data/ephemeral/home/level2-objectdetection-cv-10/develop/yumin/mmdetection/work_dirs/cascade_rcnn_r50_fpn_1x_swin_trash
# 2024-01-14 01:44:58,447 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2024-01-14 01:44:58,448 - mmdet - INFO - workflow: [('train', 1)], max: 20 epochs
# 2024-01-14 01:44:58,448 - mmdet - INFO - Checkpoints will be saved to /data/ephemeral/home/level2-objectdetection-cv-10/develop/yumin/mmdetection/work_dirs/cascade_rcnn_r50_fpn_1x_swin_trash by HardDiskBackend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 2
#       1 # 모델 학습
# ----> 2 train_detector(model, datasets[0], cfg, distributed=False, validate=False)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/apis/train.py:244, in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     242 elif cfg.load_from:
#     243     runner.load_checkpoint(cfg.load_from)
# --> 244 runner.run(data_loaders, cfg.workflow)
#
# File /opt/conda/lib/python3.10/site-packages/mmcv/runner/epoch_based_runner.py:136, in EpochBasedRunner.run(self, data_loaders, workflow, max_epochs, **kwargs)
#     134             if mode == 'train' and self.epoch >= self._max_epochs:
#     135                 break
# --> 136             epoch_runner(data_loaders[i], **kwargs)
#     138 time.sleep(1)  # wait for some hooks like loggers to finish
#     139 self.call_hook('after_run')
#
# File /opt/conda/lib/python3.10/site-packages/mmcv/runner/epoch_based_runner.py:53, in EpochBasedRunner.train(self, data_loader, **kwargs)
#      51 self._inner_iter = i
#      52 self.call_hook('before_train_iter')
# ---> 53 self.run_iter(data_batch, train_mode=True, **kwargs)
#      54 self.call_hook('after_train_iter')
#      55 del self.data_batch
#
# File /opt/conda/lib/python3.10/site-packages/mmcv/runner/epoch_based_runner.py:31, in EpochBasedRunner.run_iter(self, data_batch, train_mode, **kwargs)
#      28     outputs = self.batch_processor(
#      29         self.model, data_batch, train_mode=train_mode, **kwargs)
#      30 elif train_mode:
# ---> 31     outputs = self.model.train_step(data_batch, self.optimizer,
#      32                                     **kwargs)
#      33 else:
#      34     outputs = self.model.val_step(data_batch, self.optimizer, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/mmcv/parallel/data_parallel.py:77, in MMDataParallel.train_step(self, *inputs, **kwargs)
#      71         raise RuntimeError(
#      72             'module must have its parameters and buffers '
#      73             f'on device {self.src_device_obj} (device_ids[0]) but '
#      74             f'found one of them on device: {t.device}')
#      76 inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
# ---> 77 return self.module.train_step(*inputs[0], **kwargs[0])
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/detectors/base.py:248, in BaseDetector.train_step(self, data, optimizer)
#     221 def train_step(self, data, optimizer):
#     222     """The iteration step during training.
#     223
#     224     This method defines an iteration step during training, except for the
#    (...)
#     246               averaging the logs.
#     247     """
# --> 248     losses = self(**data)
#     249     loss, log_vars = self._parse_losses(losses)
#     251     outputs = dict(
#     252         loss=loss, log_vars=log_vars, num_samples=len(data['img_metas']))
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/mmcv/runner/fp16_utils.py:116, in auto_fp16.<locals>.auto_fp16_wrapper.<locals>.new_func(*args, **kwargs)
#     113     raise TypeError('@auto_fp16 can only be used to decorate the '
#     114                     f'method of those classes {supported_types}')
#     115 if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 116     return old_func(*args, **kwargs)
#     118 # get the arg spec of the decorated method
#     119 args_info = getfullargspec(old_func)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/detectors/base.py:172, in BaseDetector.forward(self, img, img_metas, return_loss, **kwargs)
#     169     return self.onnx_export(img[0], img_metas[0])
#     171 if return_loss:
# --> 172     return self.forward_train(img, img_metas, **kwargs)
#     173 else:
#     174     return self.forward_test(img, img_metas, **kwargs)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/detectors/two_stage.py:135, in TwoStageDetector.forward_train(self, img, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, gt_masks, proposals, **kwargs)
#     132 if self.with_rpn:
#     133     proposal_cfg = self.train_cfg.get('rpn_proposal',
#     134                                       self.test_cfg.rpn)
# --> 135     rpn_losses, proposal_list = self.rpn_head.forward_train(
#     136         x,
#     137         img_metas,
#     138         gt_bboxes,
#     139         gt_labels=None,
#     140         gt_bboxes_ignore=gt_bboxes_ignore,
#     141         proposal_cfg=proposal_cfg,
#     142         **kwargs)
#     143     losses.update(rpn_losses)
#     144 else:
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/dense_heads/base_dense_head.py:335, in BaseDenseHead.forward_train(self, x, img_metas, gt_bboxes, gt_labels, gt_bboxes_ignore, proposal_cfg, **kwargs)
#     333 else:
#     334     loss_inputs = outs + (gt_bboxes, gt_labels, img_metas)
# --> 335 losses = self.loss(*loss_inputs, gt_bboxes_ignore=gt_bboxes_ignore)
#     336 if proposal_cfg is None:
#     337     return losses
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/dense_heads/rpn_head.py:93, in RPNHead.loss(self, cls_scores, bbox_preds, gt_bboxes, img_metas, gt_bboxes_ignore)
#      70 def loss(self,
#      71          cls_scores,
#      72          bbox_preds,
#      73          gt_bboxes,
#      74          img_metas,
#      75          gt_bboxes_ignore=None):
#      76     """Compute losses of the head.
#      77
#      78     Args:
#    (...)
#      91         dict[str, Tensor]: A dictionary of loss components.
#      92     """
# ---> 93     losses = super(RPNHead, self).loss(
#      94         cls_scores,
#      95         bbox_preds,
#      96         gt_bboxes,
#      97         None,
#      98         img_metas,
#      99         gt_bboxes_ignore=gt_bboxes_ignore)
#     100     return dict(
#     101         loss_rpn_cls=losses['loss_cls'], loss_rpn_bbox=losses['loss_bbox'])
#
# File /opt/conda/lib/python3.10/site-packages/mmcv/runner/fp16_utils.py:205, in force_fp32.<locals>.force_fp32_wrapper.<locals>.new_func(*args, **kwargs)
#     202     raise TypeError('@force_fp32 can only be used to decorate the '
#     203                     'method of nn.Module')
#     204 if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 205     return old_func(*args, **kwargs)
#     206 # get the arg spec of the decorated method
#     207 args_info = getfullargspec(old_func)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/dense_heads/anchor_head.py:486, in AnchorHead.loss(self, cls_scores, bbox_preds, gt_bboxes, gt_labels, img_metas, gt_bboxes_ignore)
#     483 anchor_list, valid_flag_list = self.get_anchors(
#     484     featmap_sizes, img_metas, device=device)
#     485 label_channels = self.cls_out_channels if self.use_sigmoid_cls else 1
# --> 486 cls_reg_targets = self.get_targets(
#     487     anchor_list,
#     488     valid_flag_list,
#     489     gt_bboxes,
#     490     img_metas,
#     491     gt_bboxes_ignore_list=gt_bboxes_ignore,
#     492     gt_labels_list=gt_labels,
#     493     label_channels=label_channels)
#     494 if cls_reg_targets is None:
#     495     return None
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/dense_heads/anchor_head.py:366, in AnchorHead.get_targets(self, anchor_list, valid_flag_list, gt_bboxes_list, img_metas, gt_bboxes_ignore_list, gt_labels_list, label_channels, unmap_outputs, return_sampling_results)
#     364 if gt_labels_list is None:
#     365     gt_labels_list = [None for _ in range(num_imgs)]
# --> 366 results = multi_apply(
#     367     self._get_targets_single,
#     368     concat_anchor_list,
#     369     concat_valid_flag_list,
#     370     gt_bboxes_list,
#     371     gt_bboxes_ignore_list,
#     372     gt_labels_list,
#     373     img_metas,
#     374     label_channels=label_channels,
#     375     unmap_outputs=unmap_outputs)
#     376 (all_labels, all_label_weights, all_bbox_targets, all_bbox_weights,
#     377  pos_inds_list, neg_inds_list, sampling_results_list) = results[:7]
#     378 rest_results = list(results[7:])  # user-added return values
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/core/utils/misc.py:30, in multi_apply(func, *args, **kwargs)
#      28 pfunc = partial(func, **kwargs) if kwargs else func
#      29 map_results = map(pfunc, *args)
# ---> 30 return tuple(map(list, zip(*map_results)))
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/models/dense_heads/anchor_head.py:250, in AnchorHead._get_targets_single(self, flat_anchors, valid_flags, gt_bboxes, gt_bboxes_ignore, gt_labels, img_meta, label_channels, unmap_outputs)
#     245 anchors = flat_anchors[inside_flags, :]
#     247 assign_result = self.assigner.assign(
#     248     anchors, gt_bboxes, gt_bboxes_ignore,
#     249     None if self.sampling else gt_labels)
# --> 250 sampling_result = self.sampler.sample(assign_result, anchors,
#     251                                       gt_bboxes)
#     253 num_valid_anchors = anchors.shape[0]
#     254 bbox_targets = torch.zeros_like(anchors)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/core/bbox/samplers/base_sampler.py:96, in BaseSampler.sample(self, assign_result, bboxes, gt_bboxes, gt_labels, **kwargs)
#      94     if num_expected_neg > neg_upper_bound:
#      95         num_expected_neg = neg_upper_bound
# ---> 96 neg_inds = self.neg_sampler._sample_neg(
#      97     assign_result, num_expected_neg, bboxes=bboxes, **kwargs)
#      98 neg_inds = neg_inds.unique()
#     100 sampling_result = SamplingResult(pos_inds, neg_inds, bboxes, gt_bboxes,
#     101                                  assign_result, gt_flags)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/core/bbox/samplers/random_sampler.py:82, in RandomSampler._sample_neg(self, assign_result, num_expected, **kwargs)
#      80     return neg_inds
#      81 else:
# ---> 82     return self.random_choice(neg_inds, num_expected)
#
# File ~/level2-objectdetection-cv-10/develop/yumin/mmdetection/mmdet/core/bbox/samplers/random_sampler.py:58, in RandomSampler.random_choice(self, gallery, num)
#      54     gallery = torch.tensor(gallery, dtype=torch.long, device=device)
#      55 # This is a temporary fix. We can revert the following code
#      56 # when PyTorch fixes the abnormal return of torch.randperm.
#      57 # See: https://github.com/open-mmlab/mmdetection/pull/5014
# ---> 58 perm = torch.randperm(gallery.numel())[:num].to(device=gallery.device)
#      59 rand_inds = gallery[perm]
#      60 if not is_tensor:
#
# KeyboardInterrupt:
